# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ratan Deep**

# %% [markdown]
# Current Occupation: Unemployed

# %% [markdown]
# Desired Occupation: Data Scientist

# %% [markdown]
# *I am interested in data science because Data Science is the field to analyze the whole universe by data*

# %% [markdown]
# <h3> Our code is used to take a list of integer inputs and sorting the list and give sorted list as output

# %%
a = list(map(int, input().split()))
print(sorted(a))
# Out:
# 11 2 5 9 46
# [2, 5, 9, 11, 46]

# %% [markdown]
# - one
# - two
# - three
# - four
#
#
# 1. one
# 2. two
# 3. three
# 4. four
#
#
# ![ibm%20cloud.png](attachment:ibm%20cloud.png)
